# %%
#hierarchical modeling and k mode 
#used the most granular information from v3
#used the top 150 common features from v3 
#also limited sample size

# %%
import pandas as pd
import numpy as np
import scipy as sp


from sklearn import preprocessing

from sklearn import metrics#import editdistance as edist
from sklearn.cluster import AgglomerativeClustering

from sklearn.metrics.pairwise import pairwise_distances
from sklearn import metrics
from sklearn import cluster

from sklearn.ensemble import IsolationForest

from scipy import cluster
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read in v3 data which is a dictionary of aa and what do they stand for
df =pd.read_csv('~/Documents/persona_project/original data and supplements/persona1_processed.csv')

# %%
#read in name for each segment 
names=pd.read_csv('~/Documents/persona_project/original data and supplements/names.csv')

# %%
df1=df.iloc[:,8:]
#eliminate the first 8 columns

# %%
#to make it run faster, only look at the first 150 features, and the most reacent 20000 rows 
df2=df1.iloc[:20000,:150]

# %%
#detecting outliers in outcomes
#isf=IsolationForest()
#isf.fit(df2)
#t=isf.predict(df2)
#len(np.where(t==-1)[0])
#df3=df2[t==1]

df3=df2
df3.shape
# Out:
# (20000, 150)

# %%
#hierarchical clustering with custome distance/dissimilarity metric
#https://gist.github.com/codehacken/8b9316e025beeabb082dda4d0654a6fa

# %%
#change data type from int to boolean to feed into pairwise distance
for i in range(df3.shape[1]): 
    df3.iloc[:,i]=df3.iloc[:,i].astype('bool')

# %%
# Calculate pairwise distances with the dice dissimilarity.
m = pairwise_distances(df3, df3, metric='dice') 
#http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.pairwise_distances.html
print(m)
# Out:
# [[0.         0.9047619  0.79545455 ... 0.94736842 0.58441558 0.80821918]
#  [0.9047619  0.         0.96428571 ... 0.66666667 0.95555556 0.95121951]
#  [0.79545455 0.96428571 0.         ... 0.96153846 0.84615385 0.51724138]
#  ...
#  [0.94736842 0.66666667 0.96153846 ... 0.         0.95121951 1.        ]
#  [0.58441558 0.95555556 0.84615385 ... 0.95121951 0.         0.89473684]
#  [0.80821918 0.95121951 0.51724138 ... 1.         0.89473684 0.        ]]

# %%
#remove missing. the missings here are false false values and creates negative inf val in dissimilarity matrix 
m_df=pd.DataFrame(m)
keep=m_df.index[pd.isnull(m_df).any(axis=0)==False]
m_df1=m_df.iloc[keep,keep]
m_df1.shape
m2=m_df1.values

# %%
m_df1.shape
# Out:
# (19199, 19199)

# %%
#also delete these rows in original data with label in order to match with predictions
df4=df2.iloc[keep,]

# %%
# Perform agglomerative clustering.
# The affinity is precomputed (since the distance are precalculated).
# Use an 'average' linkage. Use any other apart from  'ward'.
agg = AgglomerativeClustering(n_clusters=6, affinity='precomputed',
                              linkage='average')

# Use the distance matrix directly.
u = agg.fit_predict(m2)

# %%
#dendrogram
X = sp.spatial.distance.squareform(m2)
Z = cluster.hierarchy.linkage(X, 'average')

plt.figure()
dn = sp.cluster.hierarchy.dendrogram(Z)

# %%
metrics.silhouette_score(m2, u, metric="precomputed")
#https://www.stat.berkeley.edu/~spector/s133/Clus.html
#the cluster is weak and could potentially be artificial
# Out:
# 0.2934444865039251

# %%
#tabulate frequency for each prediction result 
unique_elements, counts_elements = np.unique(u, return_counts=True)

# %%
counts_elements
# Out:
# array([ 5959,   106, 13100,     5,    27,     2])

# %%
len(u)
# Out:
# 19199

# %%
#associate prediction with original data 
df4['label']=u
# Out:
# /Users/aiyizhang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# only look at the second cluster
df4_2=df4[df4.label==2] 
df4_2.shape
# Out:
# (13100, 151)

# %%
# find the percentage of true for each feature for label 2
#label 2 seems to be the largest one so it could potentially be the likly cardiology patient 
hm2=[]
for i in range(df4_2.iloc[:,:150].shape[1]):
    hm2.append(round(np.unique(df4_2.iloc[:,:150].iloc[:,i], return_counts=True)[1][1]/df4_2.iloc[:,:150].shape[0],2))

# %%
hm2=pd.DataFrame(list(map(list, zip(hm2, names.cat))))
hm2=hm2.sort_values(by=[0], ascending=False)

# %%
hm2
#older or middle aged: adult no presence of children (adults whose children have gronw up), generation X
#richer: single family dewell, homeowner, residential property, premium goods, high disposable income
#higher educated or acculturated: English as dominant language spoken at home
#not drinking but not exercising nor keep good diet
# Out:
#         0                                                  1
# 1    0.75  Household Composition Presence of Children Pre...
# 3    0.75  Household Composition Presence of Children Pre...
# 2    0.74  Household Composition Presence of Children Pre...
# 4    0.74  Household Composition Presence of Children Pre...
# 5    0.74  Household Composition Presence of Children Pre...
# 6    0.74  Household Composition Presence of Children Pre...
# 7    0.70  Household Composition Presence of Adults Prese...
# 8    0.69  Household Insights Household Member Language P...
# 9    0.66       Household Property Dwelling Unit Size 1 Unit
# 10   0.65  Household Property Dwelling Type Single family...
# 11   0.64   Household Property Home Ownership Type Homeowner
# 13   0.61    Household Composition Gender Presence of Female
# 15   0.60      Household Composition Gender Presence of Male
# 16   0.59  Household Property Property/Realty Indicator R...
# 12   0.55  Voting Behavior (Restricted to Political Use) ...
# 17   0.55  Household Composition Presence of Adults Prese...
# 18   0.53  Household Composition Presence of Adults Prese...
# 14   0.52  Voting Behavior (Restricted to Political Use) ...
# 22   0.49  Household Insights Direct Mail Responder Yes -...
# 23   0.48  Household Composition Presence of Children Pre...
# 0    0.48                   Net Asset Value nan $0 - $24,999
# 19   0.47                       Shopper Segments nan Premium
# 20   0.47  Buying Power Score Disposable Income: High Hou...
# 24   0.44              Demographics Generations Generation X
# 25   0.42  Voting Behavior (Restricted to Political Use) ...
# 21   0.41  Mobile App Audiences Top Downloaded Apps Top D...
# 83   0.40  Hobbies & Interests Leisure Activities/Hobbies...
# 26   0.39  Household Composition Presence of Children Pre...
# 28   0.37  Household Property Home Total Value Less than ...
# 124  0.36  Hobbies & Interests Live Theatre/Concert/Dance...
# ..    ...                                                ...
# 130  0.20  Computers & Electronics Mobile Phone Model Use...
# 143  0.20  Computers & Electronics Mobile Phone Model Use...
# 135  0.20  Computers & Electronics Mobile Phone Model Use...
# 140  0.20  Alcohol (Restricted to Best Practices) Wine Do...
# 115  0.20  Lifestyle Statements Health and Diet Active He...
# 149  0.20  Computers & Electronics Mobile Phone Model Use...
# 98   0.20  Financial Institutions nan Has Financial Accou...
# 121  0.20  Demographics Political Propensity Registered t...
# 89   0.20  Contributions (Restricted to Political Use) na...
# 114  0.20         Outlook nan Household Has Health Insurance
# 109  0.20  Computers & Electronics Mobile Phone Model Use...
# 97   0.20                      Grocery Ketchup Ketchup-Heinz
# 122  0.20  Computers & Electronics Tablets Use Mobile Dev...
# 141  0.19  Computers & Electronics Mobile Phone Model Use...
# 139  0.19  Financial Institutions nan Has Financial Accou...
# 137  0.19  Computers & Electronics Mobile Phone Model Use...
# 99   0.19  Household Products Paper Towel Paper Towels-Bo...
# 58   0.19       Demographics Generations Millennials (Gen Y)
# 131  0.19  Financial Institutions nan Has Financial Accou...
# 118  0.19  Voting Behavior (Restricted to Political Use) ...
# 134  0.18  Shopper Segments nan Made Purchase at Departme...
# 94   0.18  Financial Institutions nan Has Financial Accou...
# 116  0.18  Political Affiliations (Restricted to Politica...
# 144  0.18  Financial Institutions nan Has Financial Accou...
# 145  0.18  Beauty and Personal Care Dental Floss Oral-B D...
# 148  0.18  Financial Institutions nan Has Financial Accou...
# 125  0.18  Shopper Segments nan Bought Women's Apparel/Ac...
# 146  0.17  Financial Institutions nan Has Financial Accou...
# 91   0.16                        Shopper Segments nan Budget
# 90   0.16  Buying Power Score Disposable Income: Low Hous...
#
# [150 rows x 2 columns]

# %%
hm2.to_csv("hm2Aug24.csv")

# %%
#plot feature importance of label 2
sns.set(style="whitegrid")
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(20, 8.27)

ax = sns.barplot(x=1, y=0, data=hm2[1:70],color="grey", ax=ax)
ax.set_title('Percent Consumer per Feature for Likely Cardiolovescular Patients')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Household Composition Presence of Children Presence of Child 4-6:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 13-15:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 7-9:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 16-18:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-3:None'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult 19+'),
#  Text(0,0,'Household Insights Household Member Language Preference Household Member Speaks English'),
#  Text(0,0,'Household Property Dwelling Unit Size 1 Unit'),
#  Text(0,0,'Household Property Dwelling Type Single family dwelling unit'),
#  Text(0,0,'Household Property Home Ownership Type Homeowner'),
#  Text(0,0,'Household Composition Gender Presence of Female'),
#  Text(0,0,'Household Composition Gender Presence of Male'),
#  Text(0,0,'Household Property Property/Realty Indicator Residential Property'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2012 General Election (Restricted to Political Use)'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult Female 19+'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult Male 19+'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2008 General Election (Restricted to Political Use)'),
#  Text(0,0,'Household Insights Direct Mail Responder Yes - Direct Mail Responder'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-18: None'),
#  Text(0,0,'Net Asset Value nan $0 - $24,999'),
#  Text(0,0,'Shopper Segments nan Premium'),
#  Text(0,0,'Buying Power Score Disposable Income: High Household can afford Premium goods'),
#  Text(0,0,'Demographics Generations Generation X'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2010 General Election (Restricted to Political Use)'),
#  Text(0,0,'Mobile App Audiences Top Downloaded Apps Top Downloaded Apple Store Apps'),
#  Text(0,0,'Hobbies & Interests Leisure Activities/Hobbies Physical Fitness Program-Regular Participates Last 12 Months'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-18'),
#  Text(0,0,'Household Property Home Total Value Less than $100,000 total home value'),
#  Text(0,0,'Hobbies & Interests Live Theatre/Concert/Dance Attend Concert Last 12M'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Votes in Primary Elections (Restricted to Political Use)'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Democrat (Restricted to Political Use)'),
#  Text(0,0,'Buying Power Score Disposable Income: Average Household buys on Value'),
#  Text(0,0,'Shopper Segments nan Mid-Priced'),
#  Text(0,0,'Hobbies & Interests Leisure Activities/Hobbies Leisure/Hobby: Dining Out-Not Fast Food'),
#  Text(0,0,'Demographics Generations Baby Boomers'),
#  Text(0,0,'Household Property Property/Realty Year Built Before 1969'),
#  Text(0,0,'Travel Travel Frequency Frequent Traveller-10 Trips last 12 months'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Optimus Showtime'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Sony Ericsson'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Epic'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry q10'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Revolution'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Chase'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S7edge'),
#  Text(0,0,'Computers & Electronics Cell/Smartphones/Tablets HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to T-Mobile'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Amazon Sites Last 3Month'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Any Apparel Last 3Month'),
#  Text(0,0,'Household Composition Presence of Adults 2 adults in living unit'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Exhibit'),
#  Text(0,0,'Household Composition Presence of Adults 1 adult in living unit'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Citizens Bank'),
#  Text(0,0,'Mobile App Audiences Top Downloaded Apps Top Downloaded Google Play Apps'),
#  Text(0,0,'Finance Payment Methods Use Payment Method-Peer to Peer Payments'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: HTC Evo'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Bank of America'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S6edge'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Spirit'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry Bold'),
#  Text(0,0,'Computers & Electronics Subscriber Services HH Subscribes to Cable TV'),
#  Text(0,0,'Shopping Drug Stores Shop CVS Last 4 Weeks'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With KeyBank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Blackberry with Carrier T-Mobile'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Casio GzOne Commando'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With TD Bank'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Other Multi-National Financial Institution'),
#  Text(0,0,'Household Composition Presence of Children Number of Children in HH: One or More'),
#  Text(0,0,'Household Composition Household Size 1 person in living unit'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With E-Trade'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Blackberry')]

# %%
# only look at the second cluster
df4_0=df4[df4.label==0] 
df4_0.shape
# Out:
# (5959, 151)

# %%
# find the percentage of true for each feature for label 2
hm0=[]
for i in range(df4_0.iloc[:,:70].shape[1]):
    hm0.append(round(np.unique(df4_0.iloc[:,:70].iloc[:,i], return_counts=True)[1][0]/df4_0.iloc[:,:70].shape[0],2))
hm0[:] = [1 - x  for x in hm0]
hm0=pd.DataFrame(list(map(list, zip(hm0, names.cat))))
hm0=hm0.sort_values(by=[0], ascending=False)

# %%
hm0 #not so much information
# Out:
#        0                                                  1
# 0   0.85                   Net Asset Value nan $0 - $24,999
# 21  0.24  Mobile App Audiences Top Downloaded Apps Top D...
# 14  0.16  Voting Behavior (Restricted to Political Use) ...
# 12  0.15  Voting Behavior (Restricted to Political Use) ...
# 33  0.15  Mobile App Audiences Top Downloaded Apps Top D...
# 58  0.14       Demographics Generations Millennials (Gen Y)
# 32  0.14              Demographics Generations Baby Boomers
# 30  0.12  Buying Power Score Disposable Income: Average ...
# 27  0.12  Political Affiliations (Restricted to Politica...
# 29  0.12                    Shopper Segments nan Mid-Priced
# 25  0.10  Voting Behavior (Restricted to Political Use) ...
# 31  0.09  Voting Behavior (Restricted to Political Use) ...
# 24  0.09              Demographics Generations Generation X
# 20  0.09  Buying Power Score Disposable Income: High Hou...
# 19  0.09                       Shopper Segments nan Premium
# 44  0.08  Political Affiliations (Restricted to Politica...
# 54  0.06  Political Affiliations (Restricted to Politica...
# 34  0.05  Travel Travel Frequency Frequent Traveller-10 ...
# 62  0.05  Computers & Electronics Cell/Smartphones/Table...
# 37  0.04  Shopper Segments nan Visited WebSite:Any Appar...
# 38  0.03  Finance Payment Methods Use Payment Method-Pee...
# 42  0.03  Financial Institutions nan Has Financial Accou...
# 53  0.03  Computers & Electronics Subscriber Services HH...
# 36  0.02  Shopper Segments nan Visited WebSite:Amazon Si...
# 59  0.02  Financial Institutions nan Has Financial Accou...
# 63  0.02  Financial Institutions nan Has Financial Accou...
# 40  0.02  Computers & Electronics Mobile Phone Model Use...
# 47  0.02  Computers & Electronics Mobile Phone Model Use...
# 50  0.02  Financial Institutions nan Has Financial Accou...
# 69  0.02  Computers & Electronics Mobile Phone Model Use...
# ..   ...                                                ...
# 51  0.00  Computers & Electronics Mobile Phone Model Use...
# 60  0.00  Computers & Electronics Mobile Phone Model Use...
# 4   0.00  Household Composition Presence of Children Pre...
# 5   0.00  Household Composition Presence of Children Pre...
# 57  0.00  Computers & Electronics Mobile Phone Model Use...
# 56  0.00  Computers & Electronics Mobile Phone Model Use...
# 55  0.00  Financial Institutions nan Has Financial Accou...
# 6   0.00  Household Composition Presence of Children Pre...
# 7   0.00  Household Composition Presence of Adults Prese...
# 28  0.00  Household Property Home Total Value Less than ...
# 8   0.00  Household Insights Household Member Language P...
# 26  0.00  Household Composition Presence of Children Pre...
# 13  0.00    Household Composition Gender Presence of Female
# 23  0.00  Household Composition Presence of Children Pre...
# 22  0.00  Household Insights Direct Mail Responder Yes -...
# 18  0.00  Household Composition Presence of Adults Prese...
# 1   0.00  Household Composition Presence of Children Pre...
# 17  0.00  Household Composition Presence of Adults Prese...
# 16  0.00  Household Property Property/Realty Indicator R...
# 15  0.00      Household Composition Gender Presence of Male
# 41  0.00  Computers & Electronics Mobile Phone Brand Use...
# 49  0.00  Computers & Electronics Mobile Phone Model Use...
# 11  0.00   Household Property Home Ownership Type Homeowner
# 43  0.00  Computers & Electronics Mobile Phone Model Use...
# 10  0.00  Household Property Dwelling Type Single family...
# 45  0.00  Household Composition Presence of Adults 1 adu...
# 46  0.00  Household Composition Presence of Adults 2 adu...
# 9   0.00       Household Property Dwelling Unit Size 1 Unit
# 48  0.00  Computers & Electronics Mobile Phone Model Use...
# 35  0.00  Household Property Property/Realty Year Built ...
#
# [70 rows x 2 columns]

# %%
#plot feature importance of label 2
sns.set(style="whitegrid")
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(20, 8.27)

ax = sns.barplot(x=1, y=0, data=test_out0,color="grey", ax=ax)
ax.set_title('Percent Consumer per Feature for Likely Cardiolovescular Patients')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
#kmode
#https://pypi.org/project/kmodes/

# %%
from kmodes.kmodes import KModes

km = KModes(n_clusters=6, init='Huang', n_init=5, verbose=1)

clusters = km.fit_predict(df3)

# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 6003, cost: 436568.0
# Run 1, iteration: 2/100, moves: 2191, cost: 432392.0
# Run 1, iteration: 3/100, moves: 417, cost: 432311.0
# Run 1, iteration: 4/100, moves: 60, cost: 432298.0
# Run 1, iteration: 5/100, moves: 6, cost: 432298.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 4630, cost: 462228.0
# Run 2, iteration: 2/100, moves: 368, cost: 462228.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 5693, cost: 431449.0
# Run 3, iteration: 2/100, moves: 1524, cost: 424383.0
# Run 3, iteration: 3/100, moves: 92, cost: 424330.0
# Run 3, iteration: 4/100, moves: 19, cost: 424330.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 4746, cost: 454950.0
# Run 4, iteration: 2/100, moves: 1277, cost: 454086.0
# Run 4, iteration: 3/100, moves: 491, cost: 454086.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 5547, cost: 426116.0
# Run 5, iteration: 2/100, moves: 2307, cost: 424437.0
# Run 5, iteration: 3/100, moves: 896, cost: 423776.0
# Run 5, iteration: 4/100, moves: 180, cost: 423776.0
# Best run was number 5
# [[False  True  True  True  True  True  True  True  True  True  True  True
#   False  True False  True  True  True  True  True  True  True  True  True
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False]
#  [False  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True False  True False
#    True  True  True False False False False False False False  True False
#   False False False False False  True False  True False False False False
#   False False False  True  True False False False  True  True False False
#    True False  True False False False False False  True  True False  True
#   False False False  True False False  True  True False  True False  True
#   False False False  True False False False False False False False False
#    True False False False False False  True  True False False False False
#    True False  True False  True False False False False  True False False
#   False False  True False  True False  True False  True  True  True False
#   False  True False  True False  True  True False False False  True  True
#   False False False False False  True]
#  [ True False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False]
#  [ True  True  True  True  True  True  True  True  True  True  True False
#   False  True False False False False False False False False False  True
#   False False  True False  True False False False False False False False
#   False False False False False False False False False  True False False
#   False False False False False False False False False False False False
#   False False False False False  True False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False]
#  [ True False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False  True  True False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False]
#  [False  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True False False False  True  True
#   False  True False  True  True False False  True False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False]]

# %%
unique_elements, counts_elements = np.unique(clusters, return_counts=True)

# %%
counts_elements
# Out:
# array([3110, 2141, 7913, 2256, 1316, 3264])

# %%
df3['label']=clusters

# %%
# only look at the second cluster
df3_2=df3[df3.label==5] 
df3_2.shape
# Out:
# (3264, 151)

# %%
# find the percentage of true for each feature for label 2
testk=[1]
for i in range(df3_2.iloc[:,:150].shape[1]):
    testk.append(round(np.unique(df3_2.iloc[:,:150].iloc[:,i], return_counts=True)[1][0]/df3_2.iloc[:,:150].shape[0],2))
test_outk[:] = [1 - x  for x in test_outk]
test_outk=pd.DataFrame(list(map(list, zip(testk, names.cat))))
test_outk=test_outk.sort_values(by=[0], ascending=False)

# %%
test_outk.to_csv('kmode2Aug24.csv')

# %%
#plot feature importance of label 2
sns.set(style="whitegrid")
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(20, 8.27)

ax = sns.barplot(x=1, y=0, data=test_outk,color="grey", ax=ax)
ax.set_title('Percent Consumer per Feature for Likely Cardiolovescular Patients')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Net Asset Value nan $0 - $24,999'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Raymond James & Associates'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2010 Primary Election (Restricted to Political Use)'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Motorola Defy'),
#  Text(0,0,"Shopping Department/Discount/Warehouse Shopped Macey's Last 3M"),
#  Text(0,0,'Household Composition Household Size 2 persons in living unit'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) nan Consumed Alcoholic Drinks in the Last Month'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Google Nexus Phone'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Venice'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Morgan Stanley Smith Barney'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Capital One'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With PNC Bank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Rush'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With TD Ameritrade'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With JPMorgan Chase'),
#  Text(0,0,'Shopper Segments nan Made Purchase at Department/Discount Store Lst 3M'),
#  Text(0,0,'Grocery Ketchup Ketchup-Heinz'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: Google Nexus 10'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG G2X'),
#  Text(0,0,'Computers & Electronics Subscriber Services Use Mobile Devices for Internet Activities'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult 55-64'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: HP Touchpad'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Exhibit'),
#  Text(0,0,'Beauty and Personal Care Dental Floss Oral-B Dental Floss'),
#  Text(0,0,'Computers & Electronics Subscriber Services HH Subscribes To: Any Pay/Premium Channel'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Continuum'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult 45-54'),
#  Text(0,0,'Lifestyle Statements Health and Diet I Make Sure I Exercise Regularly'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Moto E 1st Gen'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Scottrade'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Citizens Bank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Motorola Atrix'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Casio GzOne Commando'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: HTC Droid Incredible'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Ameriprise Financial'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Ativ Odyssey'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Samsung with Carrier T-Mobile'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Purchase Wine:Q'),
#  Text(0,0,'Demographics Political Propensity Registered to Vote'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With KeyBank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Player'),
#  Text(0,0,'Household Products Paper Towel Paper Towels-Bounty'),
#  Text(0,0,'Demographics Generations Millennials (Gen Y)'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Citibank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: HTC Evo'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Voters- Undecided (Restricted to Political Use)'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Domestic Dinner Wines-Red'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Pantech Flex'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Merrill Lynch'),
#  Text(0,0,'Hobbies & Interests Leisure Activities/Hobbies Leisure/Hobby: Dining Out-Not Fast Food'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With GMAC/Ally Bank'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Domestic Dinner Wines-White'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Principal Financial'),
#  Text(0,0,'Outlook nan Household Has Health Insurance'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Fascinate Galaxy'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Any Jewelry/Luxury Goods/Accessories Last 3M'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry Curve'),
#  Text(0,0,'Household Composition Presence of Children Number of Children in HH: One or More'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Blackberry'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Beer & Ale Drink Beer - Imported'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Fifth Third Bank'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Other Multi-National Financial Institution'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With E-Trade'),
#  Text(0,0,'Computers & Electronics Wearables HH Has At Least 1 Wearable Device'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Optimus Zip'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Branch Banking and Trust'),
#  Text(0,0,'Computers & Electronics Subscriber Services HH Subscribes to Cable TV'),
#  Text(0,0,'Lifestyle Statements Health and Diet Active Health Management: Far Above Average'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: Blackberry Playbook'),
#  Text(0,0,'Household Property Property/Realty Year Built Before 1969'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S7edge'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Mega'),
#  Text(0,0,'Contributions (Restricted to Political Use) nan Made a Charitable Contribution (Restricted to Political Use)'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Purchase Wine:Kim Crawford'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: Fuhu Nabi'),
#  Text(0,0,'Shopper Segments nan Budget'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Blackberry with Carrier T-Mobile'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With American Express'),
#  Text(0,0,'Travel Activities Vacation Activities - Like To Do-Sightseeing'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Google'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Chase'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Bank of America'),
#  Text(0,0,'Shopping Drug Stores Shop CVS Last 4 Weeks'),
#  Text(0,0,'Computers & Electronics Cell/Smartphones/Tablets HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to T-Mobile'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Drink Domestic Dinner/Table Wines'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry z10'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Independent (Restricted to Political Use)'),
#  Text(0,0,"Shopper Segments nan Bought Women's Apparel/Accessories Lst 12M"),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry Bold'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Revolution'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Blackberry with Carrier Verizon'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Pantech Burst'),
#  Text(0,0,'Computers & Electronics Cell/Smartphones/Tablets HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to Verizon Wireless'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Optimus Showtime'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Epic'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Republican (Restricted to Political Use)'),
#  Text(0,0,'Finance Payment Methods Use Payment Method-Peer to Peer Payments'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Spirit'),
#  Text(0,0,'Computers & Electronics Cell/Smartphones/Tablets HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to AT&T'),
#  Text(0,0,'Household Composition Presence of Adults 2 adults in living unit'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Charles Schwab'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Any Apparel Last 3Month'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Sony Ericsson'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry q10'),
#  Text(0,0,'Computers & Electronics Subscriber Services Use Smartphones For Internet Activities'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Apple iPhone'),
#  Text(0,0,'Household Composition Household Size 1 person in living unit'),
#  Text(0,0,'Hobbies & Interests Live Theatre/Concert/Dance Attend Concert Last 12M'),
#  Text(0,0,'Household Composition Presence of Adults 1 adult in living unit'),
#  Text(0,0,'Travel Travel Frequency Frequent Traveller-10 Trips last 12 months'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Pantech Discover'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With TD Bank'),
#  Text(0,0,'Buying Power Score Disposable Income: Low Household buys on a Budget'),
#  Text(0,0,'Hobbies & Interests Leisure Activities/Hobbies Physical Fitness Program-Regular Participates Last 12 Months'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Democrat (Restricted to Political Use)'),
#  Text(0,0,'Mobile App Audiences Top Downloaded Apps Top Downloaded Google Play Apps'),
#  Text(0,0,'Household Insights Direct Mail Responder Yes - Direct Mail Responder'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S6edge'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2010 General Election (Restricted to Political Use)'),
#  Text(0,0,'Mobile App Audiences Top Downloaded Apps Top Downloaded Apple Store Apps'),
#  Text(0,0,'Buying Power Score Disposable Income: High Household can afford Premium goods'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Apple with Carrier T-Mobile'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Amazon Sites Last 3Month'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 10-12:None'),
#  Text(0,0,'Buying Power Score Disposable Income: Average Household buys on Value'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Votes in Primary Elections (Restricted to Political Use)'),
#  Text(0,0,'Shopper Segments nan Mid-Priced'),
#  Text(0,0,'Household Property Home Total Value Less than $100,000 total home value'),
#  Text(0,0,'Demographics Generations Baby Boomers'),
#  Text(0,0,'Demographics Generations Generation X'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult Female 19+'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-18: None'),
#  Text(0,0,'Shopper Segments nan Premium'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult Male 19+'),
#  Text(0,0,'Household Property Property/Realty Indicator Residential Property'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2008 General Election (Restricted to Political Use)'),
#  Text(0,0,'Household Property Dwelling Type Single family dwelling unit'),
#  Text(0,0,'Household Property Home Ownership Type Homeowner'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-18'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2012 General Election (Restricted to Political Use)'),
#  Text(0,0,'Household Property Dwelling Unit Size 1 Unit'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult 19+'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 7-9:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 4-6:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-3:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 13-15:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 16-18:None'),
#  Text(0,0,'Household Composition Gender Presence of Male'),
#  Text(0,0,'Household Insights Household Member Language Preference Household Member Speaks English'),
#  Text(0,0,'Household Composition Gender Presence of Female')]

# %%
# only look at the second cluster
df3_0=df3[df3.label==0] 
df3_0.shape
# Out:
# (3580, 151)

# %%
# find the percentage of true for each feature for label 2
testk0=[1]
for i in range(df3_0.iloc[:,:150].shape[1]):
    testk0.append(round(np.unique(df3_0.iloc[:,:150].iloc[:,i], return_counts=True)[1][1]/df3_0.iloc[:,:150].shape[0],2))
test_outk0=pd.DataFrame(list(map(list, zip(testk0, names.cat))))
test_outk0=test_outk0.sort_values(by=[0], ascending=False)

# %%
test_outk0
# Out:
#         0                                                  1
# 0    1.00                   Net Asset Value nan $0 - $24,999
# 3    0.89  Household Composition Presence of Children Pre...
# 2    0.88  Household Composition Presence of Children Pre...
# 4    0.88  Household Composition Presence of Children Pre...
# 5    0.88  Household Composition Presence of Children Pre...
# 6    0.88  Household Composition Presence of Children Pre...
# 7    0.86  Household Composition Presence of Adults Prese...
# 8    0.81  Household Insights Household Member Language P...
# 9    0.81       Household Property Dwelling Unit Size 1 Unit
# 10   0.81  Household Property Dwelling Type Single family...
# 11   0.78   Household Property Home Ownership Type Homeowner
# 1    0.76  Household Composition Presence of Children Pre...
# 14   0.70  Voting Behavior (Restricted to Political Use) ...
# 12   0.69  Voting Behavior (Restricted to Political Use) ...
# 17   0.66  Household Composition Presence of Adults Prese...
# 29   0.65                    Shopper Segments nan Mid-Priced
# 16   0.64  Household Property Property/Realty Indicator R...
# 31   0.62  Voting Behavior (Restricted to Political Use) ...
# 30   0.62  Buying Power Score Disposable Income: Average ...
# 18   0.61  Household Composition Presence of Adults Prese...
# 27   0.61  Political Affiliations (Restricted to Politica...
# 19   0.54                       Shopper Segments nan Premium
# 23   0.50  Household Composition Presence of Children Pre...
# 24   0.45              Demographics Generations Generation X
# 22   0.42  Household Insights Direct Mail Responder Yes -...
# 46   0.40  Household Composition Presence of Adults 2 adu...
# 13   0.37    Household Composition Gender Presence of Female
# 36   0.35  Shopper Segments nan Visited WebSite:Amazon Si...
# 25   0.35  Voting Behavior (Restricted to Political Use) ...
# 66   0.35  Computers & Electronics Cell/Smartphones/Table...
# ..    ...                                                ...
# 89   0.08  Contributions (Restricted to Political Use) na...
# 138  0.07  Computers & Electronics Mobile Phone Model Use...
# 44   0.07  Political Affiliations (Restricted to Politica...
# 101  0.07  Financial Institutions nan Has Financial Accou...
# 129  0.07  Computers & Electronics Mobile Phone Model Use...
# 49   0.07  Computers & Electronics Mobile Phone Model Use...
# 68   0.07  Computers & Electronics Mobile Phone Brand Use...
# 67   0.07  Financial Institutions nan Has Financial Accou...
# 121  0.07  Demographics Political Propensity Registered t...
# 21   0.06  Mobile App Audiences Top Downloaded Apps Top D...
# 105  0.06  Shopper Segments nan Visited WebSite:Any Jewel...
# 20   0.06  Buying Power Score Disposable Income: High Hou...
# 80   0.06  Computers & Electronics Mobile Phone Model Use...
# 82   0.05  Household Composition Presence of Adults Prese...
# 109  0.05  Computers & Electronics Mobile Phone Model Use...
# 93   0.05  Financial Institutions nan Has Financial Accou...
# 87   0.05  Computers & Electronics Mobile Phone Model Use...
# 118  0.04  Voting Behavior (Restricted to Political Use) ...
# 136  0.04  Computers & Electronics Mobile Phone Model Use...
# 70   0.04  Financial Institutions nan Has Financial Accou...
# 137  0.03  Computers & Electronics Mobile Phone Model Use...
# 141  0.03  Computers & Electronics Mobile Phone Model Use...
# 144  0.03  Financial Institutions nan Has Financial Accou...
# 111  0.03  Household Composition Household Size 2 persons...
# 97   0.03                      Grocery Ketchup Ketchup-Heinz
# 103  0.02  Computers & Electronics Subscriber Services Us...
# 69   0.02  Computers & Electronics Mobile Phone Model Use...
# 127  0.02  Computers & Electronics Subscriber Services HH...
# 57   0.01  Computers & Electronics Mobile Phone Model Use...
# 72   0.01  Financial Institutions nan Has Financial Accou...
#
# [151 rows x 2 columns]

# %%
#plot feature importance of label 2
sns.set(style="whitegrid")
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(20, 8.27)

ax = sns.barplot(x=1, y=0, data=test_outk0,color="grey", ax=ax)
ax.set_title('Percent Consumer per Feature for Likely Cardiolovescular Patients')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Net Asset Value nan $0 - $24,999'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 4-6:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 13-15:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 7-9:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 16-18:None'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-3:None'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult 19+'),
#  Text(0,0,'Household Insights Household Member Language Preference Household Member Speaks English'),
#  Text(0,0,'Household Property Dwelling Unit Size 1 Unit'),
#  Text(0,0,'Household Property Dwelling Type Single family dwelling unit'),
#  Text(0,0,'Household Property Home Ownership Type Homeowner'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 10-12:None'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2008 General Election (Restricted to Political Use)'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2012 General Election (Restricted to Political Use)'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult Female 19+'),
#  Text(0,0,'Shopper Segments nan Mid-Priced'),
#  Text(0,0,'Household Property Property/Realty Indicator Residential Property'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Votes in Primary Elections (Restricted to Political Use)'),
#  Text(0,0,'Buying Power Score Disposable Income: Average Household buys on Value'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult Male 19+'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Democrat (Restricted to Political Use)'),
#  Text(0,0,'Shopper Segments nan Premium'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-18: None'),
#  Text(0,0,'Demographics Generations Generation X'),
#  Text(0,0,'Household Insights Direct Mail Responder Yes - Direct Mail Responder'),
#  Text(0,0,'Household Composition Presence of Adults 2 adults in living unit'),
#  Text(0,0,'Household Composition Gender Presence of Female'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Amazon Sites Last 3Month'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2010 General Election (Restricted to Political Use)'),
#  Text(0,0,'Computers & Electronics Cell/Smartphones/Tablets HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to AT&T'),
#  Text(0,0,'Household Composition Household Size 1 person in living unit'),
#  Text(0,0,'Household Composition Gender Presence of Male'),
#  Text(0,0,'Travel Travel Frequency Frequent Traveller-10 Trips last 12 months'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S6edge'),
#  Text(0,0,'Mobile App Audiences Top Downloaded Apps Top Downloaded Google Play Apps'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With American Express'),
#  Text(0,0,'Shopper Segments nan Budget'),
#  Text(0,0,'Household Property Home Total Value Less than $100,000 total home value'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Pantech Discover'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With KeyBank'),
#  Text(0,0,'Household Composition Presence of Adults 1 adult in living unit'),
#  Text(0,0,'Hobbies & Interests Live Theatre/Concert/Dance Attend Concert Last 12M'),
#  Text(0,0,'Household Composition Presence of Children Presence of Child 0-18'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Google'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Mega'),
#  Text(0,0,'Hobbies & Interests Leisure Activities/Hobbies Leisure/Hobby: Dining Out-Not Fast Food'),
#  Text(0,0,'Hobbies & Interests Leisure Activities/Hobbies Physical Fitness Program-Regular Participates Last 12 Months'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Apple iPhone'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Fascinate Galaxy'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Player'),
#  Text(0,0,'Demographics Generations Baby Boomers'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry q10'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: Blackberry Playbook'),
#  Text(0,0,'Computers & Electronics Cell/Smartphones/Tablets HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to T-Mobile'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Epic'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Purchase Wine:Q'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Charles Schwab'),
#  Text(0,0,'Finance Payment Methods Use Payment Method-Peer to Peer Payments'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With TD Bank'),
#  Text(0,0,'Computers & Electronics Subscriber Services HH Subscribes to Cable TV'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Citibank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Spirit'),
#  Text(0,0,'Computers & Electronics Cell/Smartphones/Tablets HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to Verizon Wireless'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Sony Ericsson'),
#  Text(0,0,'Buying Power Score Disposable Income: Low Household buys on a Budget'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Beer & Ale Drink Beer - Imported'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Domestic Dinner Wines-Red'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Any Apparel Last 3Month'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Optimus Showtime'),
#  Text(0,0,'Shopping Drug Stores Shop CVS Last 4 Weeks'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With PNC Bank'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Purchase Wine:Kim Crawford'),
#  Text(0,0,'Household Products Paper Towel Paper Towels-Bounty'),
#  Text(0,0,'Household Composition Presence of Children Number of Children in HH: One or More'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry z10'),
#  Text(0,0,'Computers & Electronics Wearables HH Has At Least 1 Wearable Device'),
#  Text(0,0,'Computers & Electronics Subscriber Services Use Smartphones For Internet Activities'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: Google Nexus 10'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Ameriprise Financial'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Blackberry with Carrier Verizon'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Principal Financial'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG G2X'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Domestic Dinner Wines-White'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Morgan Stanley Smith Barney'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Pantech Burst'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Branch Banking and Trust'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry Bold'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Republican (Restricted to Political Use)'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) Wine Drink Domestic Dinner/Table Wines'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Merrill Lynch'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: Fuhu Nabi'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult 45-54'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Fifth Third Bank'),
#  Text(0,0,'Travel Activities Vacation Activities - Like To Do-Sightseeing'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Blackberry with Carrier T-Mobile'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Motorola Atrix'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Other Multi-National Financial Institution'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Apple with Carrier T-Mobile'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Casio GzOne Commando'),
#  Text(0,0,"Shopper Segments nan Bought Women's Apparel/Accessories Lst 12M"),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Pantech Flex'),
#  Text(0,0,'Demographics Generations Millennials (Gen Y)'),
#  Text(0,0,'Shopper Segments nan Made Purchase at Department/Discount Store Lst 3M'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Scottrade'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Ativ Odyssey'),
#  Text(0,0,'Beauty and Personal Care Dental Floss Oral-B Dental Floss'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand by Carrier Use Mobile Device From Samsung with Carrier T-Mobile'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: HTC Evo'),
#  Text(0,0,"Shopping Department/Discount/Warehouse Shopped Macey's Last 3M"),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With TD Ameritrade'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Citizens Bank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Blackberry Curve'),
#  Text(0,0,'Household Property Property/Realty Year Built Before 1969'),
#  Text(0,0,'Outlook nan Household Has Health Insurance'),
#  Text(0,0,'Lifestyle Statements Health and Diet Active Health Management: Far Above Average'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Revolution'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Chase'),
#  Text(0,0,'Lifestyle Statements Health and Diet I Make Sure I Exercise Regularly'),
#  Text(0,0,'Computers & Electronics Tablets Use Mobile Device: HP Touchpad'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Independent (Restricted to Political Use)'),
#  Text(0,0,'Alcohol (Restricted to Best Practices) nan Consumed Alcoholic Drinks in the Last Month'),
#  Text(0,0,'Contributions (Restricted to Political Use) nan Made a Charitable Contribution (Restricted to Political Use)'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S'),
#  Text(0,0,'Political Affiliations (Restricted to Political Use) nan Registered Voters- Undecided (Restricted to Political Use)'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Bank of America'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Motorola Defy'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy S7edge'),
#  Text(0,0,'Computers & Electronics Mobile Phone Brand Use Mobile Device From Manufacturer: Blackberry'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With E-Trade'),
#  Text(0,0,'Demographics Political Propensity Registered to Vote'),
#  Text(0,0,'Mobile App Audiences Top Downloaded Apps Top Downloaded Apple Store Apps'),
#  Text(0,0,'Shopper Segments nan Visited WebSite:Any Jewelry/Luxury Goods/Accessories Last 3M'),
#  Text(0,0,'Buying Power Score Disposable Income: High Household can afford Premium goods'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Galaxy Rush'),
#  Text(0,0,'Household Composition Presence of Adults Presence of Adult 55-64'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Venice'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With GMAC/Ally Bank'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: LG Optimus Zip'),
#  Text(0,0,'Voting Behavior (Restricted to Political Use) nan Voted in the 2010 Primary Election (Restricted to Political Use)'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Google Nexus Phone'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Capital One'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Continuum'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: HTC Droid Incredible'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With Raymond James & Associates'),
#  Text(0,0,'Household Composition Household Size 2 persons in living unit'),
#  Text(0,0,'Grocery Ketchup Ketchup-Heinz'),
#  Text(0,0,'Computers & Electronics Subscriber Services Use Mobile Devices for Internet Activities'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Moto E 1st Gen'),
#  Text(0,0,'Computers & Electronics Subscriber Services HH Subscribes To: Any Pay/Premium Channel'),
#  Text(0,0,'Computers & Electronics Mobile Phone Model Use Mobile Device: Samsung Exhibit'),
#  Text(0,0,'Financial Institutions nan Has Financial Accounts With JPMorgan Chase')]

# %%
#dbscan in sklearn does not work well

# %%
# Compute DBSCAN
db = cluster.DBSCAN(eps=0.3, min_samples=10).fit(persona2c)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

# %%
print('Estimated number of clusters: %d' % n_clusters_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(persona2c, labels))
#lots of overlapping clusters
# Out:
# Estimated number of clusters: 78
# Silhouette Coefficient: -0.187

# %%
persona2c.shape
# Out:
# (13294, 45)

# %%
persona2c
# Out:
#                                                        SPECIALTY       OS  \
# DEVICE_ID_HASHED
# DE150C9EE688003C7FAD1F54E8244538BBE49E36  Cardiovascular Disease      IOS
# 49256CF1D6DB7FFB64ED97DA03F2B16D2BCA3842  Cardiovascular Disease      IOS
# 9DA1EFE5552311977D16086EE09DFB1FCD22E99F  Cardiovascular Disease  ANDROID
# 6E327D957A871ADAAAEAA357B274CD99F0F56F5A  Cardiovascular Disease      IOS
# 76A0B8F805391608131C7FF01A0BC2455F0C621C  Cardiovascular Disease      IOS
# 38AC050AFEADBF8E7E366A72F9A1D7BA56143767  Cardiovascular Disease  ANDROID
# A0410A898A17F72B1C41B51B97DCC6ADA5525A55  Cardiovascular Disease  ANDROID
# E446CBDBBA6B50FD2DD32E36E7DA933050565922  Cardiovascular Disease      IOS
# 0E4010C0C637FF517854072CDA1DC83295EE8DC9  Cardiovascular Disease  ANDROID
# 11B8738F883B77B0C7B73C7065013015AF8B35D6  Cardiovascular Disease      IOS
# 71DC52F79A40F68D3BB336E4D09DB009B32C6479  Cardiovascular Disease  ANDROID
# 0C99F3535AA29E73347AD12756C8099947C6088B  Cardiovascular Disease      IOS
# C95257D009DCE00138267E9ED595CE55DFA99364  Cardiovascular Disease      IOS
# E7E466F37E53C87F7954AAA47671EB4293CB4B86  Cardiovascular Disease      IOS
# 90266ED617ADA36ECE79313D8B1A75E5530D0F80  Cardiovascular Disease  ANDROID
# FF2F77106CB9A177999A286E54BD0E7FC83BCD6A  Cardiovascular Disease      IOS
# 5B62265A76A71AB577B0CAE98E44E60C51B39975  Cardiovascular Disease      IOS
# E6BE6C719BDB63F0871C865BE26B0B2CFC919D30  Cardiovascular Disease      IOS
# DC9F77AAFA2FB41C186B34CB065780C0D48B9345  Cardiovascular Disease      IOS
# F2CB1392A5FC18DE50D45C19CA732EC49F7A7239  Cardiovascular Disease  ANDROID
# 81619E3EC0600C83618D0DFDFE85BF7C97322756  Cardiovascular Disease      IOS
# FB8C84BDC3A9BBDDECCFC52C96DCA6C46F9DC7C8  Cardiovascular Disease      IOS
# 2F31347C41B4CE3E40AC5F28E86618A369172DDD  Cardiovascular Disease  ANDROID
# 5AEC215B1DDB5324B6CCC38B777F38CD50CC40EA  Cardiovascular Disease      IOS
# A391981239D06220E0095AFD9148570A3B5653B8  Cardiovascular Disease      IOS
# 1B412246FF206E7E1D83BC5F880B87B18F43F793  Cardiovascular Disease  ANDROID
# C37F97B6E521A84B4665A94C70C6591D42026AA9  Cardiovascular Disease    OTHER
# A0C9467FD6BEFD7DC623789ACB09C8FC799A3BC5  Cardiovascular Disease      IOS
# A0E1B94A1D72734DD2C392B1D052B4AF7C628CF8  Cardiovascular Disease      IOS
# C2D1FF027019CD2CE0B175B102412F6E2BB89550  Cardiovascular Disease      IOS
# ...                                                          ...      ...
# 69D8C191B9C71BD19BE37CFE0A925BC65DAA97D9  Cardiovascular Disease      IOS
# CA172B14473D655220DE84CA01174BF7BB1D50A7  Cardiovascular Disease      IOS
# EF2C0F12C64C001B9F3522CC7A266A5513A3C0C7  Cardiovascular Disease  ANDROID
# DCC16EB619E2F15BFDCA139E42D9922008AA021A  Cardiovascular Disease  ANDROID
# DA6B2D1EE3D46A7ADB4897D70F29283CDE94E948  Cardiovascular Disease      IOS
# 4F9C0EB9EF5CDE4DCEF8455EC996F76EEC3F2A10  Cardiovascular Disease  ANDROID
# ED091524D04854660DF2462AD792F98EA6C12DED  Cardiovascular Disease      IOS
# 36E87B732EAE269B744ABF1D3BD356D9D4403DB4  Cardiovascular Disease      IOS
# B505319964F714A0EB5C7302A2113367FD5791AF  Cardiovascular Disease      IOS
# B8DDAE5CFBFFC4AD249C66FD6DAFE95BA6CD661E  Cardiovascular Disease  ANDROID
# 21F0842D29197E7291B5FABCD8347DAF3061C1BE  Cardiovascular Disease      IOS
# D57673FF4026581A939D905315C1466A60697EEB  Cardiovascular Disease      IOS
# 8CCB53E6602DDC71F096C0168FFB03CC08F777CB  Cardiovascular Disease      IOS
# ABFECDF27B604E4AE72DC4B3BDEAD7AA77A45A6C  Cardiovascular Disease  ANDROID
# 662BD80C9EFDB974E2556B9A754A5B2F1D1D1